# %% [markdown]
# # MongoDB

# %% [markdown]
# ### Setting things up

# %% [markdown]
# Remember to restart the kernel after running this code cell if you didn't already have pymongo installed (you only need to do this once)

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in ./anaconda3/lib/python3.11/site-packages (4.7.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./anaconda3/lib/python3.11/site-packages (from pymongo) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('localhost', 27017)

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.example # "example" is the database name

# %%
collection = db.students ## collection within database

# %% [markdown]
# ### Inserting/deleting data

# %% [markdown]
# MongoDB is made up of, in a simplified way, massive JSON objects

# %%
student = {'name': 'Cannon', 'lname': 'Johns', 'year': 3, 'major': 'economics', 'is_undergrad': True}

# %%
collection.insert_one(student) ## inserts one document
# Out:
# InsertOneResult(ObjectId('66578056efb064ea6862ab22'), acknowledged=True)

# %%
collection.delete_one({'name':'Cannon'})
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %%
students = [{'name': 'Cannon', 'lname': 'Johns', 'year': 3, 'major': 'economics', 'is_undergrad': True},
           {'name': 'Jake', 'lname': 'Antmann', 'year': 3, 'major': 'stats', 'is_undergrad': True},
           {'name': 'Ben', 'lname': 'Artuso', 'year': 5, 'major': 'github', 'is_undergrad': False}]

# %%
collection.insert_many(students)
# Out:
# InsertManyResult([ObjectId('665627bdadc172a15983e102'), ObjectId('665627bdadc172a15983e103'), ObjectId('665627bdadc172a15983e104')], acknowledged=True)

# %%
collection.delete_many({'is_undergrad':True}) ## conditional delete
# Out:
# DeleteResult({'n': 3, 'ok': 1.0}, acknowledged=True)

# %%
collection.delete_many({}) ## deletes everything
# Out:
# DeleteResult({'n': 3, 'ok': 1.0}, acknowledged=True)

# %% [markdown]
# ### Querying data

# %% [markdown]
# ## courses

# %% [markdown]
# Let's explore some example data that might be similar to the type you are creating in your projects

# %%
courses = pd.read_csv('https://raw.githubusercontent.com/methinky/forge_project2/main/test_forge%20-%20Courses.csv')
courses
# Out:
#    Course_Name   Code                            Description  \
# 0    COMM_2020  12736  Introduction to Management Accounting
# 1    STAT_1601  12564    Introduction to Data Science with R
# 2    STAT_1601  12645    Introduction to Data Science with R
# 3    STAT_1601  21031    Introduction to Data Science with R
# 4    COMM_2020  14295  Introduction to Management Accounting
# 5    COMM_3410  14730                       Commercial Law I
# 6    COMM_3410  14731                       Commercial Law I
# 7    SLAV_2360  11386                                Dracula
# 8    APMA_3110  15413     Applied Statistics and Probability
# 9    MATH_3350  15762                 Applied Linear Algebra
# 10   MATH_3350  15763                 Applied Linear Algebra
# 11   MATH_3350  15764                 Applied Linear Algebra
#
#            Instructor
# 0        Roger Martin
# 1      Prince Afriyie
# 2        Richard Ross
# 3      Prince Afriyie
# 4        Roger Martin
# 5        Sherri Moore
# 6        Sherri Moore
# 7   Stanley Stephanic
# 8         Gary Koenig
# 9        Jeffrey Holt
# 10       Jeffrey Holt
# 11       Jeffrey Holt

# %% [markdown]
# We can easily convert flat data to dictionary format with `to_dict()`

# %%
courses_dict = courses.to_dict('records')
courses_dict
# Out:
# [{'Course_Name': 'COMM_2020',
#   'Code': 12736,
#   'Description': 'Introduction to Management Accounting',
#   'Instructor': 'Roger Martin'},
#  {'Course_Name': 'STAT_1601',
#   'Code': 12564,
#   'Description': 'Introduction to Data Science with R',
#   'Instructor': 'Prince Afriyie'},
#  {'Course_Name': 'STAT_1601',
#   'Code': 12645,
#   'Description': 'Introduction to Data Science with R',
#   'Instructor': 'Richard Ross'},
#  {'Course_Name': 'STAT_1601',
#   'Code': 21031,
#   'Description': 'Introduction to Data Science with R',
#   'Instructor': 'Prince Afriyie'},
#  {'Course_Name': 'COMM_2020',
#   'Code': 14295,
#   'Description': 'Introduction to Management Accounting',
#   'Instructor': 'Roger Martin'},
#  {'Course_Name': 'COMM_3410',
#   'Code': 14730,
#   'Description': 'Commercial Law I',
#   'Instructor': 'Sherri Moore'},
#  {'Course_Name': 'COMM_3410',
#   'Code': 14731,
#   'Description': 'Commercial Law I',
#   'Instructor': 'Sherri Moore'},
#  {'Course_Name': 'SLAV_2360',
#   'Code': 11386,
#   'Description': 'Dracula',
#   'Instructor': 'Stanley Stephanic'},
#  {'Course_Name': 'APMA_3110',
#   'Code': 15413,
#   'Description': 'Applied Statistics and Probability',
#   'Instructor': 'Gary Koenig'},
#  {'Course_Name': 'MATH_3350',
#   'Code': 15762,
#   'Description': 'Applied Linear Algebra',
#   'Instructor': 'Jeffrey Holt'},
#  {'Course_Name': 'MATH_3350',
#   'Code': 15763,
#   'Description': 'Applied Linear Algebra',
#   'Instructor': 'Jeffrey Holt'},
#  {'Course_Name': 'MATH_3350',
#   'Code': 15764,
#   'Description': 'Applied Linear Algebra',
#   'Instructor': 'Jeffrey Holt'}]

# %% [markdown]
# We can then insert it into our MongoDB

# %%
courses_collection = db.courses

# %%
courses_collection.insert_many(courses_dict)
# Out:
# InsertManyResult([ObjectId('665780f9efb064ea6862ab23'), ObjectId('665780f9efb064ea6862ab24'), ObjectId('665780f9efb064ea6862ab25'), ObjectId('665780f9efb064ea6862ab26'), ObjectId('665780f9efb064ea6862ab27'), ObjectId('665780f9efb064ea6862ab28'), ObjectId('665780f9efb064ea6862ab29'), ObjectId('665780f9efb064ea6862ab2a'), ObjectId('665780f9efb064ea6862ab2b'), ObjectId('665780f9efb064ea6862ab2c'), ObjectId('665780f9efb064ea6862ab2d'), ObjectId('665780f9efb064ea6862ab2e')], acknowledged=True)

# %% [markdown]
# ## Students

# %%
students = pd.read_csv("https://raw.githubusercontent.com/methinky/forge_project2/main/test_forge%20-%20Students.csv")
students
# Out:
#    Student_ID First_Name    Last_Name                Email
# 0      rqb6bc    Melissa        Zheng  rqb6bc@virginia.edu
# 1      pfg9yq       Anya    Hariharan  pfg9yq@virginia.edu
# 2      zds3st      Isaac        Tabor  zds3st@virginia.edu
# 3      jrp86y      Peter         Park  jrp86y@virginia.edu
# 4      mcf5yc      Aryan  Prabhudesai  mcf5yc@virginia.edu
# 5      ppz2ry       Alex        Jones  ppz2ry@virginia.edu
# 6      rin7tx     Cheryl    Abernathy  rin7tx@virginia.edu
# 7      vip4my    Colleen    Lindstrom  vip4my@virginia.edu
# 8      eru9fh      Robin         Park  eru9fh@virginia.edu
# 9      fmp6yj      Laura       Peters  fmp6yj@virginia.edu
# 10     fpn8kb   Nicholas    Spielberg  fpn8kb@virginia.edu
# 11     imc4bv    Douglas     Polansky  imc4bv@virginia.edu
# 12     svw7gw     Edward          Lee  svw7gw@virginia.edu
# 13     tmz7bd   Brittney         Reed  tmz7bd@virginia.edu
# 14     wdk0je     Tyrone        Twain  wdk0je@virginia.edu
# 15     clw3dh     Felipe       Mendez  clw3dh@virginia.edu

# %%
students_dict = students.to_dict('records')
students_dict
# Out:
# [{'Student_ID': 'rqb6bc',
#   'First_Name': 'Melissa',
#   'Last_Name': 'Zheng',
#   'Email': 'rqb6bc@virginia.edu'},
#  {'Student_ID': 'pfg9yq',
#   'First_Name': 'Anya',
#   'Last_Name': 'Hariharan',
#   'Email': 'pfg9yq@virginia.edu'},
#  {'Student_ID': 'zds3st',
#   'First_Name': 'Isaac',
#   'Last_Name': 'Tabor',
#   'Email': 'zds3st@virginia.edu'},
#  {'Student_ID': 'jrp86y',
#   'First_Name': 'Peter',
#   'Last_Name': 'Park',
#   'Email': 'jrp86y@virginia.edu'},
#  {'Student_ID': 'mcf5yc',
#   'First_Name': 'Aryan',
#   'Last_Name': 'Prabhudesai',
#   'Email': 'mcf5yc@virginia.edu'},
#  {'Student_ID': 'ppz2ry',
#   'First_Name': 'Alex',
#   'Last_Name': 'Jones',
#   'Email': 'ppz2ry@virginia.edu'},
#  {'Student_ID': 'rin7tx',
#   'First_Name': 'Cheryl',
#   'Last_Name': 'Abernathy',
#   'Email': 'rin7tx@virginia.edu'},
#  {'Student_ID': 'vip4my',
#   'First_Name': 'Colleen',
#   'Last_Name': 'Lindstrom',
#   'Email': 'vip4my@virginia.edu'},
#  {'Student_ID': 'eru9fh',
#   'First_Name': 'Robin',
#   'Last_Name': 'Park',
#   'Email': 'eru9fh@virginia.edu'},
#  {'Student_ID': 'fmp6yj',
#   'First_Name': 'Laura',
#   'Last_Name': 'Peters',
#   'Email': 'fmp6yj@virginia.edu'},
#  {'Student_ID': 'fpn8kb',
#   'First_Name': 'Nicholas',
#   'Last_Name': 'Spielberg',
#   'Email': 'fpn8kb@virginia.edu'},
#  {'Student_ID': 'imc4bv',
#   'First_Name': 'Douglas',
#   'Last_Name': 'Polansky',
#   'Email': 'imc4bv@virginia.edu'},
#  {'Student_ID': 'svw7gw',
#   'First_Name': 'Edward',
#   'Last_Name': 'Lee',
#   'Email': 'svw7gw@virginia.edu'},
#  {'Student_ID': 'tmz7bd',
#   'First_Name': 'Brittney',
#   'Last_Name': 'Reed',
#   'Email': 'tmz7bd@virginia.edu'},
#  {'Student_ID': 'wdk0je',
#   'First_Name': 'Tyrone',
#   'Last_Name': 'Twain',
#   'Email': 'wdk0je@virginia.edu'},
#  {'Student_ID': 'clw3dh',
#   'First_Name': 'Felipe',
#   'Last_Name': 'Mendez',
#   'Email': 'clw3dh@virginia.edu'}]

# %%
students_collection = db.students

# %%
students_collection.insert_many(students_dict)
# Out:
# InsertManyResult([ObjectId('665783d4efb064ea6862ab2f'), ObjectId('665783d4efb064ea6862ab30'), ObjectId('665783d4efb064ea6862ab31'), ObjectId('665783d4efb064ea6862ab32'), ObjectId('665783d4efb064ea6862ab33'), ObjectId('665783d4efb064ea6862ab34'), ObjectId('665783d4efb064ea6862ab35'), ObjectId('665783d4efb064ea6862ab36'), ObjectId('665783d4efb064ea6862ab37'), ObjectId('665783d4efb064ea6862ab38'), ObjectId('665783d4efb064ea6862ab39'), ObjectId('665783d4efb064ea6862ab3a'), ObjectId('665783d4efb064ea6862ab3b'), ObjectId('665783d4efb064ea6862ab3c'), ObjectId('665783d4efb064ea6862ab3d'), ObjectId('665783d4efb064ea6862ab3e')], acknowledged=True)

# %% [markdown]
# ## StudentClasses

# %%
StudentClasses2 = pd.read_csv("https://raw.githubusercontent.com/methinky/forge_project2/main/test_forge%20-%20StudentClasses.csv")
StudentClasses2
# Out:
#      Code Student_ID
# 0   12736     rqb6bc
# 1   12736     svw7gw
# 2   12736     zds3st
# 3   12736     fmp6yj
# 4   12736     clw3dh
# 5   12564     ppx2ry
# 6   12564     pfg9yq
# 7   12564     zds3st
# 8   12564     jrp86y
# 9   12564     mcf5yc
# 10  12645     rin7tx
# 11  12645     vip4my
# 12  12645     eru9fh
# 13  12645     fmp6yj
# 14  12645     fpn8kb
# 15  21031     imc4bv
# 16  21031     svw7gw
# 17  21031     tmz7bd
# 18  21031     wdk0je
# 19  21031     clw3dh
# 20  14295     jrp86y
# 21  14295     mcf5yc
# 22  14295     eru9fh
# 23  14295     vip4my
# 24  14295     rin7tx
# 25  14730     rqb6bc
# 26  14730     pfg9yq
# 27  14730     zds3st
# 28  14730     jrp86y
# 29  14730     rin7tx
# 30  14731     vip4my
# 31  14731     eru9fh
# 32  14731     fmp6yj
# 33  14731     fpn8kb
# 34  14731     imc4bv
# 35  11386     rqb6bc
# 36  11386     pfg9yq
# 37  11386     zds3st
# 38  11386     jrp86y
# 39  11386     ppx2ry
# 40  15762     rqb6bc
# 41  15762     pfg9yq
# 42  15762     mcf5yc
# 43  15762     ppx2ry
# 44  15762     jrp86y
# 45  15763     rin7tx
# 46  15763     vip4my
# 47  15763     eru9fh
# 48  15763     fmp6yj
# 49  15763     fpn8kb
# 50  15764     imc4bv
# 51  15764     svw7gw
# 52  15764     tmz7bd
# 53  15764     wdk0je
# 54  15764     clw3dh
# 55  15413     vip4my
# 56  15413     svw7gw
# 57  15413     tmz7bd
# 58  15413     wdk0je
# 59  15413     clw3dh

# %%
students2_dict = StudentClasses2.to_dict('records')
students2_dict
# Out:
# [{'Code': 12736, 'Student_ID': 'rqb6bc'},
#  {'Code': 12736, 'Student_ID': 'svw7gw'},
#  {'Code': 12736, 'Student_ID': 'zds3st'},
#  {'Code': 12736, 'Student_ID': 'fmp6yj'},
#  {'Code': 12736, 'Student_ID': 'clw3dh'},
#  {'Code': 12564, 'Student_ID': 'ppx2ry'},
#  {'Code': 12564, 'Student_ID': 'pfg9yq'},
#  {'Code': 12564, 'Student_ID': 'zds3st'},
#  {'Code': 12564, 'Student_ID': 'jrp86y'},
#  {'Code': 12564, 'Student_ID': 'mcf5yc'},
#  {'Code': 12645, 'Student_ID': 'rin7tx'},
#  {'Code': 12645, 'Student_ID': 'vip4my'},
#  {'Code': 12645, 'Student_ID': 'eru9fh'},
#  {'Code': 12645, 'Student_ID': 'fmp6yj'},
#  {'Code': 12645, 'Student_ID': 'fpn8kb'},
#  {'Code': 21031, 'Student_ID': 'imc4bv'},
#  {'Code': 21031, 'Student_ID': 'svw7gw'},
#  {'Code': 21031, 'Student_ID': 'tmz7bd'},
#  {'Code': 21031, 'Student_ID': 'wdk0je'},
#  {'Code': 21031, 'Student_ID': 'clw3dh'},
#  {'Code': 14295, 'Student_ID': 'jrp86y'},
#  {'Code': 14295, 'Student_ID': 'mcf5yc'},
#  {'Code': 14295, 'Student_ID': 'eru9fh'},
#  {'Code': 14295, 'Student_ID': 'vip4my'},
#  {'Code': 14295, 'Student_ID': 'rin7tx'},
#  {'Code': 14730, 'Student_ID': 'rqb6bc'},
#  {'Code': 14730, 'Student_ID': 'pfg9yq'},
#  {'Code': 14730, 'Student_ID': 'zds3st'},
#  {'Code': 14730, 'Student_ID': 'jrp86y'},
#  {'Code': 14730, 'Student_ID': 'rin7tx'},
#  {'Code': 14731, 'Student_ID': 'vip4my'},
#  {'Code': 14731, 'Student_ID': 'eru9fh'},
#  {'Code': 14731, 'Student_ID': 'fmp6yj'},
#  {'Code': 14731, 'Student_ID': 'fpn8kb'},
#  {'Code': 14731, 'Student_ID': 'imc4bv'},
#  {'Code': 11386, 'Student_ID': 'rqb6bc'},
#  {'Code': 11386, 'Student_ID': 'pfg9yq'},
#  {'Code': 11386, 'Student_ID': 'zds3st'},
#  {'Code': 11386, 'Student_ID': 'jrp86y'},
#  {'Code': 11386, 'Student_ID': 'ppx2ry'},
#  {'Code': 15762, 'Student_ID': 'rqb6bc'},
#  {'Code': 15762, 'Student_ID': 'pfg9yq'},
#  {'Code': 15762, 'Student_ID': 'mcf5yc'},
#  {'Code': 15762, 'Student_ID': 'ppx2ry'},
#  {'Code': 15762, 'Student_ID': 'jrp86y'},
#  {'Code': 15763, 'Student_ID': 'rin7tx'},
#  {'Code': 15763, 'Student_ID': 'vip4my'},
#  {'Code': 15763, 'Student_ID': 'eru9fh'},
#  {'Code': 15763, 'Student_ID': 'fmp6yj'},
#  {'Code': 15763, 'Student_ID': 'fpn8kb'},
#  {'Code': 15764, 'Student_ID': 'imc4bv'},
#  {'Code': 15764, 'Student_ID': 'svw7gw'},
#  {'Code': 15764, 'Student_ID': 'tmz7bd'},
#  {'Code': 15764, 'Student_ID': 'wdk0je'},
#  {'Code': 15764, 'Student_ID': 'clw3dh'},
#  {'Code': 15413, 'Student_ID': 'vip4my'},
#  {'Code': 15413, 'Student_ID': 'svw7gw'},
#  {'Code': 15413, 'Student_ID': 'tmz7bd'},
#  {'Code': 15413, 'Student_ID': 'wdk0je'},
#  {'Code': 15413, 'Student_ID': 'clw3dh'}]

# %%
studentclasses2_collection = db.studentclasses2

# %%
studentclasses2_collection.insert_many(students2_dict)
# Out:
# InsertManyResult([ObjectId('665784c9efb064ea6862ab3f'), ObjectId('665784c9efb064ea6862ab40'), ObjectId('665784c9efb064ea6862ab41'), ObjectId('665784c9efb064ea6862ab42'), ObjectId('665784c9efb064ea6862ab43'), ObjectId('665784c9efb064ea6862ab44'), ObjectId('665784c9efb064ea6862ab45'), ObjectId('665784c9efb064ea6862ab46'), ObjectId('665784c9efb064ea6862ab47'), ObjectId('665784c9efb064ea6862ab48'), ObjectId('665784c9efb064ea6862ab49'), ObjectId('665784c9efb064ea6862ab4a'), ObjectId('665784c9efb064ea6862ab4b'), ObjectId('665784c9efb064ea6862ab4c'), ObjectId('665784c9efb064ea6862ab4d'), ObjectId('665784c9efb064ea6862ab4e'), ObjectId('665784c9efb064ea6862ab4f'), ObjectId('665784c9efb064ea6862ab50'), ObjectId('665784c9efb064ea6862ab51'), ObjectId('665784c9efb064ea6862ab52'), ObjectId('665784c9efb064ea6862ab53'), ObjectId('665784c9efb064ea6862ab54'), ObjectId('665784c9efb064ea6862ab55'), ObjectId('665784c9efb064ea6862ab56'), ObjectId('665784c9efb064ea6862ab57'), ObjectId('665784c9efb064ea6862ab58'), ObjectId('665784c9efb064ea6862ab59'), ObjectId('665784c9efb064ea6862ab5a'), ObjectId('665784c9efb064ea6862ab5b'), ObjectId('665784c9efb064ea6862ab5c'), ObjectId('665784c9efb064ea6862ab5d'), ObjectId('665784c9efb064ea6862ab5e'), ObjectId('665784c9efb064ea6862ab5f'), ObjectId('665784c9efb064ea6862ab60'), ObjectId('665784c9efb064ea6862ab61'), ObjectId('665784c9efb064ea6862ab62'), ObjectId('665784c9efb064ea6862ab63'), ObjectId('665784c9efb064ea6862ab64'), ObjectId('665784c9efb064ea6862ab65'), ObjectId('665784c9efb064ea6862ab66'), ObjectId('665784c9efb064ea6862ab67'), ObjectId('665784c9efb064ea6862ab68'), ObjectId('665784c9efb064ea6862ab69'), ObjectId('665784c9efb064ea6862ab6a'), ObjectId('665784c9efb064ea6862ab6b'), ObjectId('665784c9efb064ea6862ab6c'), ObjectId('665784c9efb064ea6862ab6d'), ObjectId('665784c9efb064ea6862ab6e'), ObjectId('665784c9efb064ea6862ab6f'), ObjectId('665784c9efb064ea6862ab70'), ObjectId('665784c9efb064ea6862ab71'), ObjectId('665784c9efb064ea6862ab72'), ObjectId('665784c9efb064ea6862ab73'), ObjectId('665784c9efb064ea6862ab74'), ObjectId('665784c9efb064ea6862ab75'), ObjectId('665784c9efb064ea6862ab76'), ObjectId('665784c9efb064ea6862ab77'), ObjectId('665784c9efb064ea6862ab78'), ObjectId('665784c9efb064ea6862ab79'), ObjectId('665784c9efb064ea6862ab7a')], acknowledged=True)

# %%
Assignments = pd.read_csv("https://raw.githubusercontent.com/methinky/forge_project2/main/test_forge%20-%20Assignments%20(1).csv")
Assignments
# Out:
#    Assignment_Id   Code Assignment_Title  Weight  Date_Due
# 0        12736E1  12736           Exam 1     0.1  02/29/24
# 1        12736E2  12736           Exam 2     0.1  03/21/24
# 2         12736M  12736          Midterm     0.2  04/14/24
# 3         12736F  12736            Final     0.6  05/04/24
# 4        12564E1  12564           Exam 1     0.1  02/20/24
# 5        12564E2  12564           Exam 2     0.1  03/28/24
# 6         12564M  12564          Midterm     0.2  04/11/24
# 7         12564F  12564            Final     0.6  05/07/24
# 8        12645E1  12645           Exam 1     0.1  05/08/24
# 9        12645E2  12645           Exam 2     0.1  03/15/24
# 10        12645M  12645          Midterm     0.2  04/22/24
# 11        12645F  12645            Final     0.6  05/09/24
# 12       21031E1  21031           Exam 1     0.1  03/06/24
# 13       21031E2  21031           Exam 2     0.1  02/07/24
# 14        21031M  21031          Midterm     0.2  06/08/24
# 15        21031F  21031            Final     0.6  05/09/24
# 16       14295E1  14295           Exam 1     0.1  05/10/24
# 17       14295E2  14295           Exam 2     0.1  05/11/24
# 18        14295M  14295          Midterm     0.2  05/12/24
# 19        14295F  14295            Final     0.6  05/13/24
# 20       14730E1  14730           Exam 1     0.1  05/14/24
# 21       14730E2  14730           Exam 2     0.1  05/15/24
# 22        14730M  14730          Midterm     0.2  05/16/24
# 23        14730F  14730            Final     0.6  05/17/24
# 24       14731E1  14731           Exam 1     0.1  05/18/24
# 25       14731E2  14731           Exam 2     0.1  05/19/24
# 26        14731M  14731          Midterm     0.2  05/20/24
# 27        14731F  14731            Final     0.6  05/21/24
# 28       11386E1  11386           Exam 1     0.1  05/22/24
# 29       11386E2  11386           Exam 2     0.1  05/23/24
# 30        11386M  11386          Midterm     0.2  05/24/24
# 31        11386F  11386            Final     0.6  05/25/24
# 32       15413E1  15413           Exam 1     0.1  05/26/24
# 33       15413E2  15413           Exam 2     0.1  05/27/24
# 34        15413M  15413          Midterm     0.2  05/28/24
# 35        15413F  15413            Final     0.6  05/29/24
# 36       16742E1  16742           Exam 1     0.1  05/30/24
# 37       16742E2  16742           Exam 2     0.1  05/31/24
# 38        16742M  16742          Midterm     0.2  06/01/24
# 39        16742F  16742            Final     0.6  06/02/24
# 40       15762E1  15762           Exam 1     0.1  05/30/24
# 41       15762E2  15762           Exam 2     0.1  05/31/24
# 42        15762M  15762          Midterm     0.2  06/01/24
# 43        15762F  15762            Final     0.6  06/02/24
# 44       15763E1  15763           Exam 1     0.1  05/30/24
# 45       15763E2  15763           Exam 2     0.1  05/31/24
# 46        15763F  15763          Midterm     0.2  06/01/24
# 47        15763M  15763            Final     0.6  06/02/24
# 48       15764E1  15764           Exam 1     0.1  05/30/24
# 49       15764E2  15764           Exam 2     0.1  05/31/24
# 50        15764M  15764          Midterm     0.2  06/01/24
# 51        15764F  15764            Final     0.6  06/02/24

# %%
assignments_dict = Assignments.to_dict('records')
assignments_dict
# Out:
# [{'Assignment_Id': '12736E1',
#   'Code': 12736,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '02/29/24'},
#  {'Assignment_Id': '12736E2',
#   'Code': 12736,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '03/21/24'},
#  {'Assignment_Id': '12736M',
#   'Code': 12736,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '04/14/24'},
#  {'Assignment_Id': '12736F',
#   'Code': 12736,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/04/24'},
#  {'Assignment_Id': '12564E1',
#   'Code': 12564,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '02/20/24'},
#  {'Assignment_Id': '12564E2',
#   'Code': 12564,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '03/28/24'},
#  {'Assignment_Id': '12564M',
#   'Code': 12564,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '04/11/24'},
#  {'Assignment_Id': '12564F',
#   'Code': 12564,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/07/24'},
#  {'Assignment_Id': '12645E1',
#   'Code': 12645,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/08/24'},
#  {'Assignment_Id': '12645E2',
#   'Code': 12645,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '03/15/24'},
#  {'Assignment_Id': '12645M',
#   'Code': 12645,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '04/22/24'},
#  {'Assignment_Id': '12645F',
#   'Code': 12645,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/09/24'},
#  {'Assignment_Id': '21031E1',
#   'Code': 21031,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '03/06/24'},
#  {'Assignment_Id': '21031E2',
#   'Code': 21031,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '02/07/24'},
#  {'Assignment_Id': '21031M',
#   'Code': 21031,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '06/08/24'},
#  {'Assignment_Id': '21031F',
#   'Code': 21031,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/09/24'},
#  {'Assignment_Id': '14295E1',
#   'Code': 14295,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/10/24'},
#  {'Assignment_Id': '14295E2',
#   'Code': 14295,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/11/24'},
#  {'Assignment_Id': '14295M',
#   'Code': 14295,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '05/12/24'},
#  {'Assignment_Id': '14295F',
#   'Code': 14295,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/13/24'},
#  {'Assignment_Id': '14730E1',
#   'Code': 14730,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/14/24'},
#  {'Assignment_Id': '14730E2',
#   'Code': 14730,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/15/24'},
#  {'Assignment_Id': '14730M',
#   'Code': 14730,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '05/16/24'},
#  {'Assignment_Id': '14730F',
#   'Code': 14730,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/17/24'},
#  {'Assignment_Id': '14731E1',
#   'Code': 14731,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/18/24'},
#  {'Assignment_Id': '14731E2',
#   'Code': 14731,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/19/24'},
#  {'Assignment_Id': '14731M',
#   'Code': 14731,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '05/20/24'},
#  {'Assignment_Id': '14731F',
#   'Code': 14731,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/21/24'},
#  {'Assignment_Id': '11386E1',
#   'Code': 11386,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/22/24'},
#  {'Assignment_Id': '11386E2',
#   'Code': 11386,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/23/24'},
#  {'Assignment_Id': '11386M',
#   'Code': 11386,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '05/24/24'},
#  {'Assignment_Id': '11386F',
#   'Code': 11386,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/25/24'},
#  {'Assignment_Id': '15413E1',
#   'Code': 15413,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/26/24'},
#  {'Assignment_Id': '15413E2',
#   'Code': 15413,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/27/24'},
#  {'Assignment_Id': '15413M',
#   'Code': 15413,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '05/28/24'},
#  {'Assignment_Id': '15413F',
#   'Code': 15413,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '05/29/24'},
#  {'Assignment_Id': '16742E1',
#   'Code': 16742,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/30/24'},
#  {'Assignment_Id': '16742E2',
#   'Code': 16742,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/31/24'},
#  {'Assignment_Id': '16742M',
#   'Code': 16742,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '06/01/24'},
#  {'Assignment_Id': '16742F',
#   'Code': 16742,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '06/02/24'},
#  {'Assignment_Id': '15762E1',
#   'Code': 15762,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/30/24'},
#  {'Assignment_Id': '15762E2',
#   'Code': 15762,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/31/24'},
#  {'Assignment_Id': '15762M',
#   'Code': 15762,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '06/01/24'},
#  {'Assignment_Id': '15762F',
#   'Code': 15762,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '06/02/24'},
#  {'Assignment_Id': '15763E1',
#   'Code': 15763,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/30/24'},
#  {'Assignment_Id': '15763E2',
#   'Code': 15763,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/31/24'},
#  {'Assignment_Id': '15763F',
#   'Code': 15763,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '06/01/24'},
#  {'Assignment_Id': '15763M',
#   'Code': 15763,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '06/02/24'},
#  {'Assignment_Id': '15764E1',
#   'Code': 15764,
#   'Assignment_Title': 'Exam 1',
#   'Weight': 0.1,
#   'Date_Due': '05/30/24'},
#  {'Assignment_Id': '15764E2',
#   'Code': 15764,
#   'Assignment_Title': 'Exam 2',
#   'Weight': 0.1,
#   'Date_Due': '05/31/24'},
#  {'Assignment_Id': '15764M',
#   'Code': 15764,
#   'Assignment_Title': 'Midterm',
#   'Weight': 0.2,
#   'Date_Due': '06/01/24'},
#  {'Assignment_Id': '15764F',
#   'Code': 15764,
#   'Assignment_Title': 'Final',
#   'Weight': 0.6,
#   'Date_Due': '06/02/24'}]

# %%
assignments_collection = db.Assignments

# %%
assignments_collection.insert_many(assignments_dict)
# Out:
# InsertManyResult([ObjectId('6657852defb064ea6862ab7b'), ObjectId('6657852defb064ea6862ab7c'), ObjectId('6657852defb064ea6862ab7d'), ObjectId('6657852defb064ea6862ab7e'), ObjectId('6657852defb064ea6862ab7f'), ObjectId('6657852defb064ea6862ab80'), ObjectId('6657852defb064ea6862ab81'), ObjectId('6657852defb064ea6862ab82'), ObjectId('6657852defb064ea6862ab83'), ObjectId('6657852defb064ea6862ab84'), ObjectId('6657852defb064ea6862ab85'), ObjectId('6657852defb064ea6862ab86'), ObjectId('6657852defb064ea6862ab87'), ObjectId('6657852defb064ea6862ab88'), ObjectId('6657852defb064ea6862ab89'), ObjectId('6657852defb064ea6862ab8a'), ObjectId('6657852defb064ea6862ab8b'), ObjectId('6657852defb064ea6862ab8c'), ObjectId('6657852defb064ea6862ab8d'), ObjectId('6657852defb064ea6862ab8e'), ObjectId('6657852defb064ea6862ab8f'), ObjectId('6657852defb064ea6862ab90'), ObjectId('6657852defb064ea6862ab91'), ObjectId('6657852defb064ea6862ab92'), ObjectId('6657852defb064ea6862ab93'), ObjectId('6657852defb064ea6862ab94'), ObjectId('6657852defb064ea6862ab95'), ObjectId('6657852defb064ea6862ab96'), ObjectId('6657852defb064ea6862ab97'), ObjectId('6657852defb064ea6862ab98'), ObjectId('6657852defb064ea6862ab99'), ObjectId('6657852defb064ea6862ab9a'), ObjectId('6657852defb064ea6862ab9b'), ObjectId('6657852defb064ea6862ab9c'), ObjectId('6657852defb064ea6862ab9d'), ObjectId('6657852defb064ea6862ab9e'), ObjectId('6657852defb064ea6862ab9f'), ObjectId('6657852defb064ea6862aba0'), ObjectId('6657852defb064ea6862aba1'), ObjectId('6657852defb064ea6862aba2'), ObjectId('6657852defb064ea6862aba3'), ObjectId('6657852defb064ea6862aba4'), ObjectId('6657852defb064ea6862aba5'), ObjectId('6657852defb064ea6862aba6'), ObjectId('6657852defb064ea6862aba7'), ObjectId('6657852defb064ea6862aba8'), ObjectId('6657852defb064ea6862aba9'), ObjectId('6657852defb064ea6862abaa'), ObjectId('6657852defb064ea6862abab'), ObjectId('6657852defb064ea6862abac'), ObjectId('6657852defb064ea6862abad'), ObjectId('6657852defb064ea6862abae')], acknowledged=True)

# %%
Grades = pd.read_csv("https://raw.githubusercontent.com/methinky/forge_project2/main/test_forge%20-%20Grades.csv")
Grades
# Out:
#     Student_ID Assignment_Id  Score Date_Submitted
# 0       rqb6bc       12736E1     78       02/29/24
# 1       rqb6bc       12736E2     92       03/21/24
# 2       rqb6bc        12736M     85       04/14/24
# 3       rqb6bc        12736F     64       05/04/24
# 4       svw7gw       12736E1     47       02/29/24
# ..         ...           ...    ...            ...
# 235     wdk0je        15762F    100       02/03/24
# 236     clw3dh       15762E1     93       03/24/24
# 237     clw3dh       15762E2    100       05/24/24
# 238     clw3dh        15762M     88       04/22/24
# 239     clw3dh        15762F     87       05/09/24
#
# [240 rows x 4 columns]

# %%
grades_dict = Grades.to_dict('records')
grades_dict
# Out:
# [{'Student_ID': 'rqb6bc',
#   'Assignment_Id': '12736E1',
#   'Score': 78,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '12736E2',
#   'Score': 92,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '12736M',
#   'Score': 85,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '12736F',
#   'Score': 64,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '12736E1',
#   'Score': 47,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '12736E2',
#   'Score': 90,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '12736M',
#   'Score': 55,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '12736F',
#   'Score': 71,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12736E1',
#   'Score': 36,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12736E2',
#   'Score': 88,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12736M',
#   'Score': 23,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12736F',
#   'Score': 59,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12736E1',
#   'Score': 80,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12736E2',
#   'Score': 40,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12736M',
#   'Score': 99,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12736F',
#   'Score': 67,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '12736E1',
#   'Score': 75,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '12736E2',
#   'Score': 53,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '12736M',
#   'Score': 48,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '12736F',
#   'Score': 82,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '12564E1',
#   'Score': 30,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '12564E2',
#   'Score': 62,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '12564M',
#   'Score': 91,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '12564F',
#   'Score': 84,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '12564E1',
#   'Score': 28,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '12564E2',
#   'Score': 77,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '12564M',
#   'Score': 43,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '12564F',
#   'Score': 96,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12564E1',
#   'Score': 52,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12564E2',
#   'Score': 89,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12564M',
#   'Score': 31,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '12564F',
#   'Score': 100,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '12564E1',
#   'Score': 65,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '12564E2',
#   'Score': 74,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '12564M',
#   'Score': 27,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '12564F',
#   'Score': 86,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '12564E1',
#   'Score': 38,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '12564E2',
#   'Score': 54,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '12564M',
#   'Score': 81,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '12564F',
#   'Score': 49,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '12645E1',
#   'Score': 93,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '12645E2',
#   'Score': 33,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '12645M',
#   'Score': 72,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '12645F',
#   'Score': 44,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '12645E1',
#   'Score': 95,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '12645E2',
#   'Score': 50,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '12645M',
#   'Score': 61,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '12645F',
#   'Score': 79,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '12645E1',
#   'Score': 20,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '12645E2',
#   'Score': 87,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '12645M',
#   'Score': 56,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '12645F',
#   'Score': 41,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12645E1',
#   'Score': 76,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12645E2',
#   'Score': 68,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12645M',
#   'Score': 29,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '12645F',
#   'Score': 97,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '12645E1',
#   'Score': 39,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '12645E2',
#   'Score': 70,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '12645M',
#   'Score': 45,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '12645F',
#   'Score': 63,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14731E1',
#   'Score': 65,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14731E2',
#   'Score': 80,
#   'Date_Submitted': '02/05/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14731M',
#   'Score': 98,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14731F',
#   'Score': 56,
#   'Date_Submitted': '04/06/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14731E1',
#   'Score': 45,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14731E2',
#   'Score': 65,
#   'Date_Submitted': '06/24/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14731M',
#   'Score': 43,
#   'Date_Submitted': '05/24/25'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14731F',
#   'Score': 98,
#   'Date_Submitted': '03/24/22'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '14731E1',
#   'Score': 87,
#   'Date_Submitted': '05/02/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '14731E2',
#   'Score': 77,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '14731M',
#   'Score': 78,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '14731F',
#   'Score': 76,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '14731E1',
#   'Score': 100,
#   'Date_Submitted': '04/05/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '14731E2',
#   'Score': 99,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '14731M',
#   'Score': 83,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '14731F',
#   'Score': 84,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '14731E1',
#   'Score': 79,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '14731E2',
#   'Score': 92,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '14731M',
#   'Score': 87,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '14731F',
#   'Score': 99,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '11386E1',
#   'Score': 80,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '11386E2',
#   'Score': 92,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '11386M',
#   'Score': 93,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '11386F',
#   'Score': 91,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '11386E1',
#   'Score': 68,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '11386E2',
#   'Score': 62,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '11386M',
#   'Score': 59,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '11386F',
#   'Score': 89,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '11386E1',
#   'Score': 77,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '11386E2',
#   'Score': 70,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '11386M',
#   'Score': 85,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '11386F',
#   'Score': 64,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '11386E1',
#   'Score': 51,
#   'Date_Submitted': '02/29/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '11386E2',
#   'Score': 81,
#   'Date_Submitted': '03/21/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '11386M',
#   'Score': 68,
#   'Date_Submitted': '04/14/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '11386F',
#   'Score': 93,
#   'Date_Submitted': '05/04/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '11386E1',
#   'Score': 73,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '11386E2',
#   'Score': 86,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '11386M',
#   'Score': 66,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '11386F',
#   'Score': 83,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15413E1',
#   'Score': 78,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15413E2',
#   'Score': 97,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15413M',
#   'Score': 87,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15413F',
#   'Score': 81,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15413E1',
#   'Score': 88,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15413E2',
#   'Score': 98,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15413M',
#   'Score': 63,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15413F',
#   'Score': 60,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15413E1',
#   'Score': 75,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15413E2',
#   'Score': 89,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15413M',
#   'Score': 96,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15413F',
#   'Score': 68,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15413E1',
#   'Score': 85,
#   'Date_Submitted': '02/20/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15413E2',
#   'Score': 95,
#   'Date_Submitted': '03/28/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15413M',
#   'Score': 73,
#   'Date_Submitted': '04/11/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15413F',
#   'Score': 86,
#   'Date_Submitted': '05/07/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15413E1',
#   'Score': 94,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15413E2',
#   'Score': 82,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15413M',
#   'Score': 76,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15413F',
#   'Score': 56,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '21031E1',
#   'Score': 62,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '21031E2',
#   'Score': 79,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '21031M',
#   'Score': 92,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '21031F',
#   'Score': 87,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '21031E1',
#   'Score': 99,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '21031E2',
#   'Score': 80,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '21031M',
#   'Score': 92,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '21031F',
#   'Score': 93,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '21031E1',
#   'Score': 91,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '21031E2',
#   'Score': 68,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '21031M',
#   'Score': 62,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '21031F',
#   'Score': 59,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '21031E1',
#   'Score': 89,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '21031E2',
#   'Score': 77,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '21031M',
#   'Score': 70,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '21031F',
#   'Score': 85,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '21031E1',
#   'Score': 64,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '21031E2',
#   'Score': 51,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '21031M',
#   'Score': 81,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '21031F',
#   'Score': 68,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14295E1',
#   'Score': 93,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14295E2',
#   'Score': 73,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14295M',
#   'Score': 86,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14295F',
#   'Score': 66,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '14295E1',
#   'Score': 83,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '14295E2',
#   'Score': 78,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '14295M',
#   'Score': 97,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '14295F',
#   'Score': 87,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14295E1',
#   'Score': 81,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14295E2',
#   'Score': 88,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14295M',
#   'Score': 98,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '14295F',
#   'Score': 63,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14295E1',
#   'Score': 60,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14295E2',
#   'Score': 75,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14295M',
#   'Score': 89,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '14295F',
#   'Score': 96,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14295E1',
#   'Score': 68,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14295E2',
#   'Score': 85,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14295M',
#   'Score': 95,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14295F',
#   'Score': 73,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '14730E1',
#   'Score': 86,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '14730E2',
#   'Score': 94,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '14730M',
#   'Score': 82,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '14730F',
#   'Score': 76,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '14730E1',
#   'Score': 56,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '14730E2',
#   'Score': 62,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '14730M',
#   'Score': 91,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '14730F',
#   'Score': 84,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '14730E1',
#   'Score': 67,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '14730E2',
#   'Score': 70,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '14730M',
#   'Score': 77,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'zds3st',
#   'Assignment_Id': '14730F',
#   'Score': 53,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14730E1',
#   'Score': 97,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14730E2',
#   'Score': 78,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14730M',
#   'Score': 65,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '14730F',
#   'Score': 58,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14730E1',
#   'Score': 72,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14730E2',
#   'Score': 80,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14730M',
#   'Score': 66,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '14730F',
#   'Score': 87,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '15762E1',
#   'Score': 79,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '15762E2',
#   'Score': 92,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '15762M',
#   'Score': 87,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'rqb6bc',
#   'Assignment_Id': '15762F',
#   'Score': 99,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '15762E1',
#   'Score': 80,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '15762E2',
#   'Score': 92,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '15762M',
#   'Score': 93,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'pfg9yq',
#   'Assignment_Id': '15762F',
#   'Score': 91,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '15762E1',
#   'Score': 68,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '15762E2',
#   'Score': 62,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '15762M',
#   'Score': 59,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'mcf5yc',
#   'Assignment_Id': '15762F',
#   'Score': 72,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '15762E1',
#   'Score': 92,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '15762E2',
#   'Score': 83,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '15762M',
#   'Score': 76,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'ppx2ry',
#   'Assignment_Id': '15762F',
#   'Score': 55,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '15762E1',
#   'Score': 85,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '15762E2',
#   'Score': 77,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '15762M',
#   'Score': 90,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'jrp86y',
#   'Assignment_Id': '15762F',
#   'Score': 95,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '15762E1',
#   'Score': 88,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '15762E2',
#   'Score': 90,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '15762M',
#   'Score': 77,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'rin7tx',
#   'Assignment_Id': '15762F',
#   'Score': 95,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15762E1',
#   'Score': 90,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15762E2',
#   'Score': 72,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15762M',
#   'Score': 88,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'vip4my',
#   'Assignment_Id': '15762F',
#   'Score': 100,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '15762E1',
#   'Score': 88,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '15762E2',
#   'Score': 90,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '15762M',
#   'Score': 95,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'eru9fh',
#   'Assignment_Id': '15762F',
#   'Score': 72,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '15762E1',
#   'Score': 80,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '15762E2',
#   'Score': 85,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '15762M',
#   'Score': 90,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'fmp6yj',
#   'Assignment_Id': '15762F',
#   'Score': 95,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '15762E1',
#   'Score': 90,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '15762E2',
#   'Score': 95,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '15762M',
#   'Score': 100,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'fpn8kb',
#   'Assignment_Id': '15762F',
#   'Score': 86,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '15762E1',
#   'Score': 90,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '15762E2',
#   'Score': 92,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '15762M',
#   'Score': 100,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'imc4bv',
#   'Assignment_Id': '15762F',
#   'Score': 83,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15762E1',
#   'Score': 90,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15762E2',
#   'Score': 92,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15762M',
#   'Score': 100,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'svw7gw',
#   'Assignment_Id': '15762F',
#   'Score': 83,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15762E1',
#   'Score': 90,
#   'Date_Submitted': '05/08/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15762E2',
#   'Score': 93,
#   'Date_Submitted': '03/15/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15762M',
#   'Score': 100,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'tmz7bd',
#   'Assignment_Id': '15762F',
#   'Score': 85,
#   'Date_Submitted': '05/09/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15762E1',
#   'Score': 93,
#   'Date_Submitted': '04/03/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15762E2',
#   'Score': 100,
#   'Date_Submitted': '05/06/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15762M',
#   'Score': 85,
#   'Date_Submitted': '03/04/24'},
#  {'Student_ID': 'wdk0je',
#   'Assignment_Id': '15762F',
#   'Score': 100,
#   'Date_Submitted': '02/03/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15762E1',
#   'Score': 93,
#   'Date_Submitted': '03/24/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15762E2',
#   'Score': 100,
#   'Date_Submitted': '05/24/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15762M',
#   'Score': 88,
#   'Date_Submitted': '04/22/24'},
#  {'Student_ID': 'clw3dh',
#   'Assignment_Id': '15762F',
#   'Score': 87,
#   'Date_Submitted': '05/09/24'}]

# %%
grades_collection = db.Grades

# %%
grades_collection.insert_many(grades_dict)
# Out:
# InsertManyResult([ObjectId('66578584efb064ea6862abaf'), ObjectId('66578584efb064ea6862abb0'), ObjectId('66578584efb064ea6862abb1'), ObjectId('66578584efb064ea6862abb2'), ObjectId('66578584efb064ea6862abb3'), ObjectId('66578584efb064ea6862abb4'), ObjectId('66578584efb064ea6862abb5'), ObjectId('66578584efb064ea6862abb6'), ObjectId('66578584efb064ea6862abb7'), ObjectId('66578584efb064ea6862abb8'), ObjectId('66578584efb064ea6862abb9'), ObjectId('66578584efb064ea6862abba'), ObjectId('66578584efb064ea6862abbb'), ObjectId('66578584efb064ea6862abbc'), ObjectId('66578584efb064ea6862abbd'), ObjectId('66578584efb064ea6862abbe'), ObjectId('66578584efb064ea6862abbf'), ObjectId('66578584efb064ea6862abc0'), ObjectId('66578584efb064ea6862abc1'), ObjectId('66578584efb064ea6862abc2'), ObjectId('66578584efb064ea6862abc3'), ObjectId('66578584efb064ea6862abc4'), ObjectId('66578584efb064ea6862abc5'), ObjectId('66578584efb064ea6862abc6'), ObjectId('66578584efb064ea6862abc7'), ObjectId('66578584efb064ea6862abc8'), ObjectId('66578584efb064ea6862abc9'), ObjectId('66578584efb064ea6862abca'), ObjectId('66578584efb064ea6862abcb'), ObjectId('66578584efb064ea6862abcc'), ObjectId('66578584efb064ea6862abcd'), ObjectId('66578584efb064ea6862abce'), ObjectId('66578584efb064ea6862abcf'), ObjectId('66578584efb064ea6862abd0'), ObjectId('66578584efb064ea6862abd1'), ObjectId('66578584efb064ea6862abd2'), ObjectId('66578584efb064ea6862abd3'), ObjectId('66578584efb064ea6862abd4'), ObjectId('66578584efb064ea6862abd5'), ObjectId('66578584efb064ea6862abd6'), ObjectId('66578584efb064ea6862abd7'), ObjectId('66578584efb064ea6862abd8'), ObjectId('66578584efb064ea6862abd9'), ObjectId('66578584efb064ea6862abda'), ObjectId('66578584efb064ea6862abdb'), ObjectId('66578584efb064ea6862abdc'), ObjectId('66578584efb064ea6862abdd'), ObjectId('66578584efb064ea6862abde'), ObjectId('66578584efb064ea6862abdf'), ObjectId('66578584efb064ea6862abe0'), ObjectId('66578584efb064ea6862abe1'), ObjectId('66578584efb064ea6862abe2'), ObjectId('66578584efb064ea6862abe3'), ObjectId('66578584efb064ea6862abe4'), ObjectId('66578584efb064ea6862abe5'), ObjectId('66578584efb064ea6862abe6'), ObjectId('66578584efb064ea6862abe7'), ObjectId('66578584efb064ea6862abe8'), ObjectId('66578584efb064ea6862abe9'), ObjectId('66578584efb064ea6862abea'), ObjectId('66578584efb064ea6862abeb'), ObjectId('66578584efb064ea6862abec'), ObjectId('66578584efb064ea6862abed'), ObjectId('66578584efb064ea6862abee'), ObjectId('66578584efb064ea6862abef'), ObjectId('66578584efb064ea6862abf0'), ObjectId('66578584efb064ea6862abf1'), ObjectId('66578584efb064ea6862abf2'), ObjectId('66578584efb064ea6862abf3'), ObjectId('66578584efb064ea6862abf4'), ObjectId('66578584efb064ea6862abf5'), ObjectId('66578584efb064ea6862abf6'), ObjectId('66578584efb064ea6862abf7'), ObjectId('66578584efb064ea6862abf8'), ObjectId('66578584efb064ea6862abf9'), ObjectId('66578584efb064ea6862abfa'), ObjectId('66578584efb064ea6862abfb'), ObjectId('66578584efb064ea6862abfc'), ObjectId('66578584efb064ea6862abfd'), ObjectId('66578584efb064ea6862abfe'), ObjectId('66578584efb064ea6862abff'), ObjectId('66578584efb064ea6862ac00'), ObjectId('66578584efb064ea6862ac01'), ObjectId('66578584efb064ea6862ac02'), ObjectId('66578584efb064ea6862ac03'), ObjectId('66578584efb064ea6862ac04'), ObjectId('66578584efb064ea6862ac05'), ObjectId('66578584efb064ea6862ac06'), ObjectId('66578584efb064ea6862ac07'), ObjectId('66578584efb064ea6862ac08'), ObjectId('66578584efb064ea6862ac09'), ObjectId('66578584efb064ea6862ac0a'), ObjectId('66578584efb064ea6862ac0b'), ObjectId('66578584efb064ea6862ac0c'), ObjectId('66578584efb064ea6862ac0d'), ObjectId('66578584efb064ea6862ac0e'), ObjectId('66578584efb064ea6862ac0f'), ObjectId('66578584efb064ea6862ac10'), ObjectId('66578584efb064ea6862ac11'), ObjectId('66578584efb064ea6862ac12'), ObjectId('66578584efb064ea6862ac13'), ObjectId('66578584efb064ea6862ac14'), ObjectId('66578584efb064ea6862ac15'), ObjectId('66578584efb064ea6862ac16'), ObjectId('66578584efb064ea6862 ...

# %% [markdown]
# Just like how we create data with dictionaries, we query data the same way

# %% [markdown]
# ## QUERY

# %%
query = {'first_name': 'Adam'}
employee_collection.find_one(query) ## finds one
# Out:
# {'_id': ObjectId('66562808adc172a15983e105'),
#  'employee_id': 1,
#  'first_name': 'Adam',
#  'last_name': 'Anderson',
#  'age': 34,
#  'job_title': 'Sales Manager',
#  'team': 'A',
#  'email': 'adama@gmail.com',
#  'phone_number': 4341728463}

# %%
query = {'team': 'A'}
employee_collection.find(query) ## finds everyone on team A

# %%
query = {'team': 'A'}
result = employee_collection.find(query)

# %%
for e in result:
    print(e)
# Out:
# {'_id': ObjectId('66562808adc172a15983e105'), 'employee_id': 1, 'first_name': 'Adam', 'last_name': 'Anderson', 'age': 34, 'job_title': 'Sales Manager', 'team': 'A', 'email': 'adama@gmail.com', 'phone_number': 4341728463}
# {'_id': ObjectId('66562808adc172a15983e107'), 'employee_id': 3, 'first_name': 'Cody', 'last_name': 'Covington', 'age': 24, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'codyc@gmail.com', 'phone_number': 4342672819}
# {'_id': ObjectId('66562808adc172a15983e109'), 'employee_id': 5, 'first_name': 'Evan', 'last_name': 'Earhart', 'age': 43, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'evane@gmail.com', 'phone_number': 4341529805}
# {'_id': ObjectId('66562808adc172a15983e10b'), 'employee_id': 7, 'first_name': 'Grace', 'last_name': 'Gaetz', 'age': 27, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'graceg@gmail.com', 'phone_number': 4347869041}
# {'_id': ObjectId('66562808adc172a15983e10d'), 'employee_id': 9, 'first_name': 'Igor', 'last_name': 'Irvin', 'age': 43, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'igori@gmail.com', 'phone_number': 4347759109}
# {'_id': ObjectId('66562821adc172a15983e10f'), 'employee_id': 1, 'first_name': 'Adam', 'last_name': 'Anderson', 'age': 34, 'job_title': 'Sales Manager', 'team': 'A', 'email': 'adama@gmail.com', 'phone_number': 4341728463}
# {'_id': ObjectId('66562821adc172a15983e111'), 'employee_id': 3, 'first_name': 'Cody', 'last_name': 'Covington', 'age': 24, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'codyc@gmail.com', 'phone_number': 4342672819}
# {'_id': ObjectId('66562821adc172a15983e113'), 'employee_id': 5, 'first_name': 'Evan', 'last_name': 'Earhart', 'age': 43, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'evane@gmail.com', 'phone_number': 4341529805}
# {'_id': ObjectId('66562821adc172a15983e115'), 'employee_id': 7, 'first_name': 'Grace', 'last_name': 'Gaetz', 'age': 27, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'graceg@gmail.com', 'phone_number': 4347869041}
# {'_id': ObjectId('66562821adc172a15983e117'), 'employee_id': 9, 'first_name': 'Igor', 'last_name': 'Irvin', 'age': 43, 'job_title': 'Sales Representative', 'team': 'A', 'email': 'igori@gmail.com', 'phone_number': 4347759109}

# %% [markdown]
# We can use prettyprint to make things a bit more human readable

# %%
import pprint

# %%
query = {'team': 'A'}
result = employee_collection.find(query)

# %%
for e in result:
    pprint.pprint(e)
# Out:
# {'_id': ObjectId('66562808adc172a15983e105'),
#  'age': 34,
#  'email': 'adama@gmail.com',
#  'employee_id': 1,
#  'first_name': 'Adam',
#  'job_title': 'Sales Manager',
#  'last_name': 'Anderson',
#  'phone_number': 4341728463,
#  'team': 'A'}
# {'_id': ObjectId('66562808adc172a15983e107'),
#  'age': 24,
#  'email': 'codyc@gmail.com',
#  'employee_id': 3,
#  'first_name': 'Cody',
#  'job_title': 'Sales Representative',
#  'last_name': 'Covington',
#  'phone_number': 4342672819,
#  'team': 'A'}
# {'_id': ObjectId('66562808adc172a15983e109'),
#  'age': 43,
#  'email': 'evane@gmail.com',
#  'employee_id': 5,
#  'first_name': 'Evan',
#  'job_title': 'Sales Representative',
#  'last_name': 'Earhart',
#  'phone_number': 4341529805,
#  'team': 'A'}
# {'_id': ObjectId('66562808adc172a15983e10b'),
#  'age': 27,
#  'email': 'graceg@gmail.com',
#  'employee_id': 7,
#  'first_name': 'Grace',
#  'job_title': 'Sales Representative',
#  'last_name': 'Gaetz',
#  'phone_number': 4347869041,
#  'team': 'A'}
# {'_id': ObjectId('66562808adc172a15983e10d'),
#  'age': 43,
#  'email': 'igori@gmail.com',
#  'employee_id': 9,
#  'first_name': 'Igor',
#  'job_title': 'Sales Representative',
#  'last_name': 'Irvin',
#  'phone_number': 4347759109,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e10f'),
#  'age': 34,
#  'email': 'adama@gmail.com',
#  'employee_id': 1,
#  'first_name': 'Adam',
#  'job_title': 'Sales Manager',
#  'last_name': 'Anderson',
#  'phone_number': 4341728463,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e111'),
#  'age': 24,
#  'email': 'codyc@gmail.com',
#  'employee_id': 3,
#  'first_name': 'Cody',
#  'job_title': 'Sales Representative',
#  'last_name': 'Covington',
#  'phone_number': 4342672819,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e113'),
#  'age': 43,
#  'email': 'evane@gmail.com',
#  'employee_id': 5,
#  'first_name': 'Evan',
#  'job_title': 'Sales Representative',
#  'last_name': 'Earhart',
#  'phone_number': 4341529805,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e115'),
#  'age': 27,
#  'email': 'graceg@gmail.com',
#  'employee_id': 7,
#  'first_name': 'Grace',
#  'job_title': 'Sales Representative',
#  'last_name': 'Gaetz',
#  'phone_number': 4347869041,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e117'),
#  'age': 43,
#  'email': 'igori@gmail.com',
#  'employee_id': 9,
#  'first_name': 'Igor',
#  'job_title': 'Sales Representative',
#  'last_name': 'Irvin',
#  'phone_number': 4347759109,
#  'team': 'A'}

# %%
age_query = {'age': {'$lt': 30}} ## find every employee under 30 (lt is less than)
result = employee_collection.find(age_query)

# %%
for e in result:
    pprint.pprint(e)
# Out:
# {'_id': ObjectId('66562808adc172a15983e107'),
#  'age': 24,
#  'email': 'codyc@gmail.com',
#  'employee_id': 3,
#  'first_name': 'Cody',
#  'job_title': 'Sales Representative',
#  'last_name': 'Covington',
#  'phone_number': 4342672819,
#  'team': 'A'}
# {'_id': ObjectId('66562808adc172a15983e10a'),
#  'age': 23,
#  'email': 'frankf@gmail.com',
#  'employee_id': 6,
#  'first_name': 'Frank',
#  'job_title': 'Sales Representative',
#  'last_name': 'Falconer',
#  'phone_number': 4341678923,
#  'team': 'B'}
# {'_id': ObjectId('66562808adc172a15983e10b'),
#  'age': 27,
#  'email': 'graceg@gmail.com',
#  'employee_id': 7,
#  'first_name': 'Grace',
#  'job_title': 'Sales Representative',
#  'last_name': 'Gaetz',
#  'phone_number': 4347869041,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e111'),
#  'age': 24,
#  'email': 'codyc@gmail.com',
#  'employee_id': 3,
#  'first_name': 'Cody',
#  'job_title': 'Sales Representative',
#  'last_name': 'Covington',
#  'phone_number': 4342672819,
#  'team': 'A'}
# {'_id': ObjectId('66562821adc172a15983e114'),
#  'age': 23,
#  'email': 'frankf@gmail.com',
#  'employee_id': 6,
#  'first_name': 'Frank',
#  'job_title': 'Sales Representative',
#  'last_name': 'Falconer',
#  'phone_number': 4341678923,
#  'team': 'B'}
# {'_id': ObjectId('66562821adc172a15983e115'),
#  'age': 27,
#  'email': 'graceg@gmail.com',
#  'employee_id': 7,
#  'first_name': 'Grace',
#  'job_title': 'Sales Representative',
#  'last_name': 'Gaetz',
#  'phone_number': 4347869041,
#  'team': 'A'}

# %% [markdown]
# We can also choose to only output information that we need, through selecting columns

# %%
for e in result:
    pprint.pprint(e['first_name'])

# %% [markdown]
# For these test databases, it is good practice to delete once you are done, so you do not take up space on your computer

# %%
employee_collection.delete_many({}) ## always delete at end
# Out:
# DeleteResult({'n': 20, 'ok': 1.0}, acknowledged=True)
